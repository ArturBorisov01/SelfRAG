# %%
# !pip install sentence-transformers

# %%
# !pip install sentence-transformers PyPDF2
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 6.8 MB/s eta 0:00:00
# ...

# %%
import PyPDF2
from google.colab import drive # Import drive from google.colab

# Mount Google Drive
drive.mount('/content/drive') # Mount Google Drive to access files

# 2. Function to extract text from PDF and convert to paragraphs with vectors
def pdf_to_paragraphs_with_vectors(pdf_path):
    with open(pdf_path, 'rb') as pdf_file:
        pdf_reader = PyPDF2.PdfReader(pdf_file)
        text = ""
        for page_num in range(len(pdf_reader.pages)):
            page = pdf_reader.pages[page_num]
            text += page.extract_text()

    paragraphs = text.split('\n\n')
    # 2. Filter out empty paragraphs to avoid issues with vectorization
    paragraphs = [p for p in paragraphs if p.strip()]
    paragraph_vectors = model.encode(paragraphs)
    return paragraphs, paragraph_vectors

# 3. Example usage with your PDF file path
pdf_path = '/content/drive/MyDrive/практикум РР/doc1.pdf'

paragraphs, vectors = pdf_to_paragraphs_with_vectors(pdf_path)

# 4. Display the results
for i, (paragraph, vector) in enumerate(zip(paragraphs, vectors)):
    # print(f"Paragraph {i+1}:\n{paragraph}\n")
    print(f"Vector: {vector[:10]}...\n")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Vector: [ 0.0592954  -0.044607    0.00284122  0.00257831 -0.04940589 -0.03332463
#   0.05441326  0.02832504 -0.03992751  0.0170875 ]...
